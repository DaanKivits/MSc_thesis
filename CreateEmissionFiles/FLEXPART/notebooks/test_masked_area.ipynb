# %%
import numpy as np
import netCDF4 as nc
from scipy import stats
import os
import shutil
import glob
import matplotlib.pyplot as plt
from CreateEmissionFiles.functions.fluxfile_functions import *

dirname = '/projects/0/ctdas/awoude/NRT/ICOS_OUTPUT/'
variablelist = ['nep','fire']
luyear = 2017

# %%
fluxstring_2017, fluxstring_2018 = ([] for i in range(2))
for name in variablelist:
    for month in range (4,11):
        fluxstring_2018 += sorted(glob.glob(dirname + name + '.20180' + str(month) + '.nc')) + sorted(glob.glob(dirname + name + '.2018' + str(month) + '.nc'))
        fluxstring_2017 += sorted(glob.glob(dirname + name + '.20170' + str(month) + '.nc')) + sorted(glob.glob(dirname + name + '.2017' + str(month) + '.nc'))

luvar_nc = nc.Dataset(fluxstring_2018[0],'r', format='NETCDF3_CLASSIC')
fluxname = list(luvar_nc.variables.keys())[3]
array = luvar_nc.variables[fluxname]
lu = get_lu(array)
luvar_nc.close()

for types in np.unique(lu):
#for types in [0]:
    print("WORKING ON ... " + str(types))
    
    outdir = '/projects/0/ctdas/dkivits/DATA/fluxes/2018-' + str(luyear)  + '_per_lu_' + str(types) + '/'
    if not os.path.exists(outdir):
        os.mkdir(outdir)
    
    if os.path.exists(outdir):
        shutil.rmtree(outdir)
        os.mkdir(outdir)

    for file in fluxstring_2018:
        # Progress report
        print('WORKING ON ... ' + file)
         
        # Create new filename
        basename = os.path.basename(file)
        lu_filename = fluxstring_2017[fluxstring_2018.index(file)]
        new_filename = outdir + '/' + basename
       
        ## Copy NC file to destination
        shutil.copy(file,new_filename)
        exchange_fluxes_based_on_landuse(lu_filename, new_filename, types)
# Out:
# /scratch-local/rdkok/ipykernel_2325724/2752620699.py:13: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   a = stats.mode(arr.reshape(shape), axis=1)[0]
# /scratch-local/rdkok/ipykernel_2325724/2752620699.py:14: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
# ...

# %%
check_mask(lu_filename, types)

# %%
types = 0 
lu_filename = fluxstring_2017[0]

data = nc.Dataset(lu_filename, mode = 'r')
timevar = data.variables['time'][:]
print(data.variables.items())
print(list(data.variables.keys())[3])
for timeindex, time in enumerate(timevar):
    for name, var in data.variables.items():
        if name in variablelist:
            var = data.variables[name][timeindex,:,:]
# Out:
# dict_items([('time', <class 'netCDF4._netCDF4.Variable'>
# float64 time(time)
#     standard_name: time
#     units: seconds since 2000-01-01T00:00:00Z
#     calendar: standard
#     axis: T
# unlimited dimensions: time
# current shape = (720,)
# filling off), ('longitude', <class 'netCDF4._netCDF4.Variable'>
# float64 longitude(longitude)
#     standard_name: longitude
#     long_name: longitude
#     units: degrees_east
#     axis: X
# unlimited dimensions:
# current shape = (250,)
# filling off), ('latitude', <class 'netCDF4._netCDF4.Variable'>
# float64 latitude(latitude)
#     standard_name: latitude
#     long_name: latitude
#     units: degrees_north
#     axis: Y
# unlimited dimensions:
# current shape = (390,)
# filling off), ('nep', <class 'netCDF4._netCDF4.Variable'>
# float32 nep(time, latitude, longitude)
#     long_name: nep CO2 fluxes
#     dtype: float
#     units: mol m-2 s-1
# unlimited dimensions: time
# current shape = (720, 390, 250)
# filling off)])
# nep
